# %% [markdown]
# <a href="https://colab.research.google.com/github/GustavoCavarlho/App-expo-Conex-o25/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("digite um número:"))
num2 = int(input("digite um número:"))

resultado_soma = num1+num2
resultado_subtracao = num1-num2

print(resultado_soma)
print(resultado_subtracao)
# Out:
# digite um número:5
# digite um número:7
# 12
# -2
